# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Change Working Directory to "course_selection" Folder

# %%
# %cd "/content/drive/MyDrive/course_selection"
# Out:
# /content/drive/MyDrive/course_selection

# %% [markdown]
# # Pip Install NLTK

# %%
# !pip install --upgrade nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (7.1.2)

# %% [markdown]
# # Main

# %%
#@title Main Code
import csv
import os
import requests
import tqdm.auto
import time
import re
import os
import pandas as pd
from get_faculty_info import *
from bs4 import BeautifulSoup

base_url = "http://catalog.mit.edu"
catalog_soup = BeautifulSoup(requests.get(base_url).text, features="html.parser")
schools = catalog_soup.find_all(class_="nav levelthree")[3:29] # doing 3:29 because that currently gives all of the links to school sites

# check if csv file for professors already exists
if os.path.exists('mit_professor_data_raw.csv'):
    exist_flag = True
    df = pd.read_csv('mit_professor_data_raw.csv')
else:
    exist_flag = False

# obtain all strings like /schools/{school_name}/{sub_school}
string = str(catalog_soup)
pattern = re.compile(r"/schools/(\w+[-\w]+)/(\w+[-\w]+)/")
matches = pattern.finditer(string)
school_hrefs = list(set([x.group() for x in matches]))

print("Gathering professor info...")

keys = set()
professors = []
pbar = tqdm.tqdm()
for school_href in school_hrefs:
    school_name = school_href.split('/')[-2] # get the sub_school name
    url = base_url + school_href + "#facultystafftext" # get the url of all faculty
    page = ''
    while page == '':
        try:
            page = requests.get(url)
            break
        except:
            print("Connection refused by the server..")
            print("Let me sleep for 5 seconds")
            print("ZZzzzz...")
            time.sleep(5)
            print("Was a nice sleep, now let me continue...")
            continue
    faculty_soup = BeautifulSoup(page.text, features="html.parser")
    faculty_list = faculty_soup.find_all(class_="noindent name")
    for faculty in faculty_list:
        item = {}
        name = faculty.text.split(',')[0]
        item["name"] = name
        item["school_affiliation"] = school_name
        if not exist_flag:
            # get_faculty_info() -> This function should be able to obtain a brief description about a faculty member given the faculty name. Should return a string containing keywords or brief description of their research interests.
            keywords = get_faculty_info(name,school_name)
            item["keywords"] = keywords
            keys.update(item.keys())
            professors.append(item)
        else:
            if name not in df.name.to_numpy(): # only continue if the name is not already in the datafrane
                # get_faculty_info() -> This function should be able to obtain a brief description about a faculty member given the faculty name. Should return a string containing keywords or brief description of their research interests.
                keywords = get_faculty_info(name,school_name)
                item["keywords"] = keywords
                keys.update(item.keys())
                professors.append(item)
        pbar.update()

print("Writing professor data...")
if not exist_flag:
    with open("mit_professor_data_raw.csv", "w", newline="\n", encoding="utf8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=keys)
        writer.writeheader()
        for c in tqdm.tqdm(professors):
            writer.writerow(c)
else:
    with open("mit_professor_data_raw.csv", "a", newline="\n", encoding="utf8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=keys)
        for c in tqdm.tqdm(professors):
            writer.writerow(c)
# Out:
# Gathering professor info...
# 351it [37:37,  6.43s/it]
# 3it [00:14,  4.55s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 4it [00:22,  5.93s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 5it [00:30,  6.69s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 6it [00:38,  7.15s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 7it [00:46,  7.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 8it [00:54,  7.63s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 9it [01:02,  7.76s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 16it [01:36,  4.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 17it [01:44,  5.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 18it [01:52,  6.42s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 19it [02:00,  6.90s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 20it [02:08,  7.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 27it [02:40,  4.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 28it [02:48,  5.49s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 29it [02:56,  6.26s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 30it [03:04,  6.79s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 31it [03:12,  7.17s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 33it [03:24,  6.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 38it [03:48,  4.57s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 39it [03:56,  5.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 40it [04:04,  6.34s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 41it [04:12,  6.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 42it [04:20,  7.21s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 44it [04:32,  6.22s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 49it [04:56,  4.68s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 50it [05:04,  5.69s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 51it [05:12,  6.39s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 52it [05:20,  6.89s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 53it [05:28,  7.23s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 56it [05:43,  5.59s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 60it [06:02,  4.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 61it [06:10,  5.52s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 62it [06:18,  6.28s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 63it [06:26,  6.81s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 64it [06:34,  7.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 67it [06:50,  5.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 71it [07:09,  4.49s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 72it [07:17,  5.56s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 73it [07:25,  6.30s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 74it [07:33,  6.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 75it [07:41,  7.19s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 78it [07:56,  5.47s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 82it [08:14,  4.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 83it [08:22,  5.48s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 84it [08:30,  6.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 85it [08:38,  6.78s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 86it [08:46,  7.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 89it [09:01,  5.39s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 90it [09:09,  6.19s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 91it [09:17,  6.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 95it [09:36,  4.70s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 96it [09:44,  5.70s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 97it [09:52,  6.41s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 100it [10:07,  5.20s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 101it [10:15,  6.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 102it [10:23,  6.65s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 106it [10:41,  4.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 107it [10:49,  5.64s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 108it [10:57,  6.36s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 111it [11:12,  5.11s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 112it [11:20,  5.99s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 113it [11:28,  6.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 117it [11:47,  4.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 118it [11:55,  5.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 119it [12:03,  6.41s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 122it [12:18,  5.21s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 123it [12:26,  6.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 124it [12:35,  6.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 127it [12:52,  5.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 128it [13:00,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 132it [13:21,  5.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 134it [13:34,  5.81s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 135it [13:42,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 138it [14:00,  5.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 139it [14:08,  6.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 143it [14:29,  5.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 145it [14:41,  5.49s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 146it [14:49,  6.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 149it [15:06,  5.55s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 150it [15:14,  6.30s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 154it [15:35,  5.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 156it [15:47,  5.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 157it [15:56,  6.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 160it [16:12,  5.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 161it [16:20,  6.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 165it [16:41,  5.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 167it [16:54,  5.57s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 168it [17:02,  6.31s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 171it [17:19,  5.63s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 172it [17:27,  6.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 176it [17:48,  5.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 178it [18:00,  5.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 179it [18:08,  6.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 180it [18:16,  6.80s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 181it [18:24,  7.17s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 182it [18:32,  7.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 183it [18:41,  7.63s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 184it [18:49,  7.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 185it [18:57,  7.84s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 186it [19:05,  7.90s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 187it [19:13,  7.94s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 188it [19:21,  7.98s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 189it [19:29,  8.00s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 190it [19:37,  8.01s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 191it [19:45,  8.02s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 192it [19:53,  8.03s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 199it [20:27,  4.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 200it [20:35,  5.73s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 201it [20:43,  6.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 202it [20:51,  6.91s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 203it [20:59,  7.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 205it [21:12,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 208it [21:28,  5.63s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 209it [21:36,  6.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 210it [21:45,  6.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 214it [22:03,  4.84s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 215it [22:11,  5.80s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 216it [22:19,  6.47s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 219it [22:35,  5.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 220it [22:43,  6.19s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 221it [22:52,  6.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 226it [23:16,  4.80s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 227it [23:24,  5.77s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 228it [23:32,  6.46s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 231it [23:48,  5.63s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 232it [23:56,  6.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 235it [24:12,  5.37s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 236it [24:20,  6.17s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 237it [24:29,  6.73s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 238it [24:37,  7.14s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 242it [24:56,  4.90s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 243it [25:04,  5.84s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 246it [25:18,  4.91s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 247it [25:26,  5.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 248it [25:35,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 249it [25:43,  6.97s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 253it [26:03,  5.33s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 254it [26:12,  6.14s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 258it [26:32,  4.91s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 259it [26:40,  5.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 260it [26:48,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 262it [26:59,  5.92s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 264it [27:11,  5.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 265it [27:20,  6.54s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 269it [27:39,  4.95s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 270it [27:47,  5.88s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 271it [27:55,  6.53s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 273it [28:07,  6.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 275it [28:19,  5.70s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 286it [29:04,  3.97s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 287it [29:12,  5.19s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 288it [29:20,  6.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 289it [29:28,  6.65s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 290it [29:36,  7.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 291it [29:45,  7.36s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 292it [29:53,  7.56s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 293it [30:01,  7.71s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 294it [30:09,  7.81s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 301it [30:42,  4.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 302it [30:50,  5.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 303it [30:58,  6.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 304it [31:06,  6.91s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 305it [31:14,  7.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 312it [31:48,  4.64s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 313it [31:56,  5.66s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 314it [32:04,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 315it [32:12,  6.97s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 316it [32:20,  7.29s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 322it [32:47,  4.36s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 323it [32:55,  5.46s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 324it [33:04,  6.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 325it [33:12,  6.78s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 326it [33:20,  7.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 327it [33:28,  7.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 328it [33:36,  7.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 329it [33:44,  7.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 330it [33:52,  7.83s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 336it [34:19,  4.58s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 337it [34:27,  5.62s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 338it [34:35,  6.34s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 339it [34:43,  6.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 340it [34:51,  7.21s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 341it [34:59,  7.46s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 348it [35:32,  4.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 349it [35:40,  5.71s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 350it [35:48,  6.41s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 351it [35:56,  6.90s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 352it [36:04,  7.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 358it [36:34,  4.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 359it [36:42,  5.81s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 361it [36:55,  5.93s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 362it [37:03,  6.56s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 363it [37:11,  7.01s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 369it [37:41,  4.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 370it [37:49,  5.78s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 372it [38:01,  5.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 373it [38:09,  6.51s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 374it [38:17,  6.97s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 380it [38:47,  4.78s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 381it [38:55,  5.76s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 383it [39:07,  5.78s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 384it [39:15,  6.46s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 385it [39:23,  6.93s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 390it [39:49,  5.23s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 391it [39:57,  6.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 394it [40:13,  5.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 395it [40:21,  6.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 396it [40:29,  6.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 401it [40:54,  4.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 402it [41:02,  5.79s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 405it [41:19,  5.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 406it [41:27,  6.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 407it [41:35,  6.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 412it [42:00,  4.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 413it [42:08,  5.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 416it [42:24,  5.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 417it [42:32,  6.11s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 418it [42:40,  6.69s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 419it [42:48,  7.09s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 420it [42:56,  7.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 426it [43:24,  4.47s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 427it [43:32,  5.54s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 428it [43:40,  6.29s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 429it [43:48,  6.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 430it [43:56,  7.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 431it [44:04,  7.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 437it [44:32,  4.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 438it [44:40,  5.64s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 439it [44:48,  6.36s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 440it [44:56,  6.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 441it [45:04,  7.22s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 442it [45:12,  7.47s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 448it [45:39,  4.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 449it [45:47,  5.52s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 450it [45:55,  6.28s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 451it [46:03,  6.81s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 452it [46:11,  7.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 453it [46:19,  7.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 454it [46:27,  7.62s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 460it [46:53,  4.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 461it [47:01,  5.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 462it [47:09,  6.20s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 463it [47:17,  6.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 464it [47:25,  7.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 465it [47:33,  7.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 472it [48:04,  4.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 473it [48:12,  5.34s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 474it [48:20,  6.15s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 475it [48:28,  6.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 476it [48:36,  7.12s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 477it [48:44,  7.39s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 478it [48:52,  7.59s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 479it [49:00,  7.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 480it [49:09,  7.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 481it [49:17,  7.89s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 487it [49:42,  4.39s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 488it [49:50,  5.49s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 489it [49:58,  6.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 490it [50:06,  6.79s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 491it [50:14,  7.17s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 492it [50:22,  7.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 498it [50:48,  4.21s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 499it [50:57,  5.36s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 500it [51:05,  6.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 501it [51:13,  6.73s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 502it [51:21,  7.12s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 503it [51:29,  7.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 509it [51:55,  4.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 510it [52:03,  5.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 511it [52:11,  6.19s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 512it [52:19,  6.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 513it [52:27,  7.14s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 514it [52:35,  7.41s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 520it [53:02,  4.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 521it [53:10,  5.46s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 522it [53:18,  6.23s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 523it [53:26,  6.78s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 524it [53:34,  7.16s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 525it [53:42,  7.42s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 526it [53:50,  7.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 527it [53:58,  7.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 533it [54:23,  4.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 534it [54:32,  5.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 535it [54:40,  6.18s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 536it [54:48,  6.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 537it [54:56,  7.13s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 538it [55:04,  7.40s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 539it [55:12,  7.59s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 540it [55:21,  8.10s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 541it [55:29,  8.09s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 542it [55:37,  8.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 543it [55:45,  8.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 544it [55:53,  8.06s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 545it [56:01,  8.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 546it [56:09,  8.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 547it [56:17,  8.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 548it [56:25,  8.04s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 549it [56:33,  8.04s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 550it [56:41,  8.04s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 551it [56:49,  8.04s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 554it [57:06,  6.06s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 555it [57:14,  6.66s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 556it [57:22,  7.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 557it [57:30,  7.36s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 558it [57:38,  7.57s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 559it [57:46,  7.71s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 565it [58:14,  4.50s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 566it [58:22,  5.56s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 567it [58:30,  6.32s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 568it [58:38,  6.83s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 569it [58:46,  7.20s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 570it [58:54,  7.45s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 576it [59:18,  4.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 577it [59:27,  5.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 578it [59:35,  6.10s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 579it [59:43,  6.68s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 580it [59:51,  7.09s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 581it [59:59,  7.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 587it [1:00:23,  4.03s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 588it [1:00:32,  5.23s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 589it [1:00:40,  6.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 590it [1:00:48,  6.67s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 591it [1:00:56,  7.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 592it [1:01:04,  7.37s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 598it [1:01:28,  4.04s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 599it [1:01:36,  5.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 600it [1:01:45,  6.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 601it [1:01:53,  6.67s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 602it [1:02:01,  7.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 603it [1:02:09,  7.37s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 609it [1:02:34,  4.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 610it [1:02:42,  5.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 611it [1:02:50,  6.10s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 612it [1:02:58,  6.69s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 613it [1:03:06,  7.10s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 614it [1:03:14,  7.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 615it [1:03:22,  7.58s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 616it [1:03:30,  7.72s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 617it [1:03:38,  7.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 623it [1:04:03,  4.11s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 624it [1:04:11,  5.29s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 625it [1:04:19,  6.11s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 626it [1:04:27,  6.69s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 627it [1:04:35,  7.10s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 628it [1:04:43,  7.38s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 635it [1:05:16,  4.48s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 636it [1:05:24,  5.55s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 637it [1:05:32,  6.30s/it]
# Connection refused by the server..
# ...
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2218it [3:50:05,  7.60s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2219it [3:50:13,  7.73s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2220it [3:50:21,  7.83s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2221it [3:50:29,  7.89s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2222it [3:50:37,  7.94s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2223it [3:50:45,  7.97s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2224it [3:50:53,  7.99s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2225it [3:51:01,  8.01s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2226it [3:51:09,  8.02s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2227it [3:51:17,  8.03s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2234it [3:51:51,  4.55s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2235it [3:51:59,  5.60s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2236it [3:52:07,  6.33s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2237it [3:52:15,  6.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2238it [3:52:23,  7.21s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2240it [3:52:35,  6.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2242it [3:52:46,  5.73s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2246it [3:53:04,  4.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2247it [3:53:12,  5.52s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2248it [3:53:20,  6.28s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2249it [3:53:29,  6.81s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2251it [3:53:40,  6.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2252it [3:53:48,  6.65s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2253it [3:53:56,  7.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2256it [3:54:11,  5.41s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2259it [3:54:26,  4.74s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2260it [3:54:34,  5.73s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2262it [3:54:45,  5.48s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2263it [3:54:53,  6.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2264it [3:55:01,  6.83s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2265it [3:55:10,  7.20s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2266it [3:55:18,  7.45s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2267it [3:55:26,  7.63s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2268it [3:55:34,  7.75s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2269it [3:55:42,  7.84s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2275it [3:56:08,  4.31s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2276it [3:56:16,  5.43s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2277it [3:56:24,  6.22s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2278it [3:56:32,  6.76s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2279it [3:56:40,  7.15s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2280it [3:56:48,  7.42s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2286it [3:57:14,  4.26s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2287it [3:57:22,  5.39s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2288it [3:57:31,  6.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2289it [3:57:39,  6.86s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2290it [3:57:47,  7.22s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2291it [3:57:55,  7.47s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2292it [3:58:03,  7.64s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2293it [3:58:11,  7.76s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2294it [3:58:19,  7.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2295it [3:58:27,  7.91s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2302it [3:59:01,  4.79s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2303it [3:59:09,  5.77s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2304it [3:59:17,  6.45s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2305it [3:59:25,  6.93s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2306it [3:59:33,  7.27s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2312it [4:00:03,  4.79s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2313it [4:00:11,  5.76s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2314it [4:00:19,  6.45s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2315it [4:00:27,  6.93s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2316it [4:00:35,  7.26s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2323it [4:01:09,  4.71s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2324it [4:01:17,  5.71s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2325it [4:01:25,  6.41s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2326it [4:01:33,  6.90s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2327it [4:01:41,  7.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2332it [4:02:06,  4.87s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2333it [4:02:14,  5.83s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2334it [4:02:22,  6.49s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2335it [4:02:30,  6.96s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2338it [4:02:45,  5.39s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2339it [4:02:53,  6.19s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2343it [4:03:12,  4.77s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2344it [4:03:20,  5.76s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2345it [4:03:28,  6.44s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2346it [4:03:36,  6.92s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2349it [4:03:51,  5.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2350it [4:03:59,  6.15s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2354it [4:04:18,  4.50s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2355it [4:04:26,  5.56s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2356it [4:04:34,  6.31s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2357it [4:04:42,  6.83s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2360it [4:04:56,  5.23s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2361it [4:05:04,  6.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2365it [4:05:23,  4.56s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2366it [4:05:31,  5.61s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2367it [4:05:39,  6.34s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2368it [4:05:47,  6.85s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2371it [4:06:02,  5.23s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2372it [4:06:10,  6.07s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2376it [4:06:28,  4.47s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2377it [4:06:36,  5.54s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2378it [4:06:44,  6.29s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2379it [4:06:52,  6.82s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2381it [4:07:03,  6.01s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2382it [4:07:11,  6.62s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2383it [4:07:19,  7.05s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2384it [4:07:27,  7.35s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2389it [4:07:50,  4.67s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2390it [4:07:58,  5.68s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2392it [4:08:11,  5.84s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2393it [4:08:19,  6.50s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2394it [4:08:27,  6.97s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2395it [4:08:35,  7.29s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2401it [4:09:04,  4.67s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2403it [4:09:16,  5.29s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2404it [4:09:24,  6.11s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2405it [4:09:32,  6.69s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2406it [4:09:40,  7.10s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2408it [4:09:52,  6.25s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2412it [4:10:10,  4.64s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2414it [4:10:23,  5.24s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# 2415it [4:10:31,  6.08s/it]
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
